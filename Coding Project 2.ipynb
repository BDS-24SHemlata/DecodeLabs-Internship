# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\dell\Downloads\Dataset for Data Analytics.xlsx')

print("Dataset loaded!")
print("Total rows:", len(df))
print("Total columns:", len(df.columns))
print("\nColumns:", df.columns.tolist())
# Out:
# Dataset loaded!
# Total rows: 1200
# Total columns: 14
#
# Columns: ['OrderID', 'Date', 'CustomerID', 'Product', 'Quantity', 'UnitPrice', 'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber', 'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice']

# %%
print("========== BASIC STATISTICS ==========")
print(df.describe())
# Out:
# ========== BASIC STATISTICS ==========
#                       Date     Quantity    UnitPrice  ItemsInCart   TotalPrice
# count                 1200  1200.000000  1200.000000  1200.000000  1200.000000
# mean   2024-03-22 16:58:48     2.945833   356.412750     5.485000  1053.968300
# min    2023-01-01 00:00:00     1.000000    11.390000     1.000000    11.390000
# 25%    2023-08-03 18:00:00     2.000000   186.062500     4.000000   410.520000
# 50%    2024-03-23 00:00:00     3.000000   364.210000     5.000000   823.615000
# 75%    2024-11-08 12:00:00     4.000000   521.570000     7.000000  1578.475000
# max    2025-06-30 00:00:00     5.000000   699.930000    10.000000  3456.400000
# std                    NaN     1.407557   197.177146     2.281983   819.856558

# %%
print("========== PRODUCT ANALYSIS ==========")
print("\nKitni baar har product bika:")
print(df['Product'].value_counts())

print("\nHar product ki average price:")
print(df.groupby('Product')['TotalPrice'].mean().round(2))
# Out:
# ========== PRODUCT ANALYSIS ==========
#
# Kitni baar har product bika:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64
#
# Har product ki average price:
# Product
# Chair      1098.99
# Desk        985.06
# Laptop     1110.56
# Monitor    1077.62
# Phone       972.58
# Printer    1080.73
# Tablet     1042.28
# Name: TotalPrice, dtype: float64

# %%
print("========== PAYMENT METHOD ==========")
print(df['PaymentMethod'].value_counts())

print("\n========== ORDER STATUS ==========")
print(df['OrderStatus'].value_counts())

print("\n========== REFERRAL SOURCE ==========")
print(df['ReferralSource'].value_counts())
# Out:
# ========== PAYMENT METHOD ==========
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64
#
# ========== ORDER STATUS ==========
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64
#
# ========== REFERRAL SOURCE ==========
# ReferralSource
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64
